# %%
import pandas as pd

# %%
DATASET_LOCATION="./dataset/expandedDataSet.csv"

# %%
ds = pd.read_csv(DATASET_LOCATION)

# %%
ds.head(10)
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0           0  female         NaN   bachelor's degree      standard
# 1           1  female     group C        some college      standard
# 2           2  female     group B     master's degree      standard
# 3           3    male     group A  associate's degree  free/reduced
# 4           4    male     group C        some college      standard
# 5           5  female     group B  associate's degree      standard
# 6           6  female     group B        some college      standard
# 7           7    male     group B        some college  free/reduced
# 8           8    male     group D         high school  free/reduced
# 9           9  female     group B         high school  free/reduced
#
#     TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0       none             married     regularly          yes         3.0
# 1        NaN             married     sometimes          yes         0.0
# 2       none              single     sometimes          yes         4.0
# 3       none             married         never           no         1.0
# 4       none             married     sometimes          yes         0.0
# 5       none             married     regularly          yes         1.0
# 6  completed             widowed         never           no         1.0
# 7       none             married     sometimes          yes         1.0
# 8  completed              single     sometimes           no         3.0
# 9       none             married     regularly          yes         NaN
#
#   TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0     school_bus            < 5         71            71            74
# 1            NaN         5 - 10         69            90            88
# 2     school_bus            < 5         87            93            91
# 3            NaN         5 - 10         45            56            42
# 4     school_bus         5 - 10         76            78            75
# 5     school_bus         5 - 10         73            84            79
# 6        private         5 - 10         85            93            89
# 7        private           > 10         41            43            39
# 8        private           > 10         65            64            68
# 9        private            < 5         37            59            50

# %% [markdown]
# <h1><b>DESCRIZIONE DEGLI ATTRIBUTI</b></h1>
# <ul>
#     <li><b>Gender:</b> Gender of the student (male/female)</li>
#     <li><b>EthnicGroup:</b> Ethnic group of the student (group A to E)</li>
#     <li><b>ParentEduc:</b> Parent(s) education background (from some_highschool to master's degree)</li>
#     <li><b>LunchType:</b> School lunch type (standard or free/reduced)</li>
#     <li><b>TestPrep:</b> Test preparation course followed (completed or none)</li>
#     <li><b>ParentMaritalStatus:</b> Parent(s) marital status (married/single/widowed/divorced)</li>
#     <li><b>PracticeSport:</b> How often the student parctice sport (never/sometimes/regularly))</li>
#     <li><b>IsFirstChild:</b> If the child is first child in the family or not (yes/no)</li>
#     <li><b>NrSiblings:</b> Number of siblings the student has (0 to 7)</li>
#     <li><b>TransportMeans:</b> Means of transport to school (schoolbus/private)</li>
#     <li><b>WklyStudyHours:</b> Weekly self-study hours(less that 5hrs; between 5 and 10hrs; more than 10hrs)</li>
#     <li><b>MathScore:</b> math test score(0-100)</li>
#     <li><b>ReadingScore:</b> reading test score(0-100)</li>
#     <li><b>WritingScore:</b> writing test score(0-100)</li>
# </ul>

# %%
#elimino la colonna TestPrep perchè ha troppi dati mancanti
ds.drop("TestPrep",axis=1,inplace=True)

# %%
#elimino la colonna indice perchè non è significativa
ds.drop("Unnamed: 0",axis=1,inplace=True)

# %%
#elimino la colonna LunchType perchè non sono sicuro che sia significativa
ds.drop("LunchType",axis=1,inplace=True)

# %%
ds.head(10)
# Out:
#    Gender EthnicGroup          ParentEduc ParentMaritalStatus PracticeSport  \
# 0  female         NaN   bachelor's degree             married     regularly
# 1  female     group C        some college             married     sometimes
# 2  female     group B     master's degree              single     sometimes
# 3    male     group A  associate's degree             married         never
# 4    male     group C        some college             married     sometimes
# 5  female     group B  associate's degree             married     regularly
# 6  female     group B        some college             widowed         never
# 7    male     group B        some college             married     sometimes
# 8    male     group D         high school              single     sometimes
# 9  female     group B         high school             married     regularly
#
#   IsFirstChild  NrSiblings TransportMeans WklyStudyHours  MathScore  \
# 0          yes         3.0     school_bus            < 5         71
# 1          yes         0.0            NaN         5 - 10         69
# 2          yes         4.0     school_bus            < 5         87
# 3           no         1.0            NaN         5 - 10         45
# 4          yes         0.0     school_bus         5 - 10         76
# 5          yes         1.0     school_bus         5 - 10         73
# 6           no         1.0        private         5 - 10         85
# 7          yes         1.0        private           > 10         41
# 8           no         3.0        private           > 10         65
# 9          yes         NaN        private            < 5         37
#
#    ReadingScore  WritingScore
# 0            71            74
# 1            90            88
# 2            93            91
# 3            56            42
# 4            78            75
# 5            84            79
# 6            93            89
# 7            43            39
# 8            64            68
# 9            59            50

# %%
ds.shape
# Out:
# (30641, 12)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   EthnicGroup          28801 non-null  object
#  2   ParentEduc           28796 non-null  object
#  3   ParentMaritalStatus  29451 non-null  object
#  4   PracticeSport        30010 non-null  object
#  5   IsFirstChild         29737 non-null  object
#  6   NrSiblings           29069 non-null  float64
#  7   TransportMeans       27507 non-null  object
#  8   WklyStudyHours       29686 non-null  object
#  9   MathScore            30641 non-null  int64
#  10  ReadingScore         30641 non-null  int64
#  11  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 2.8+ MB

# %%
#eliminiamo le osservazioni che presentano dati mancanti
ds.dropna(inplace=True)

# %%
#Mappiamo Gender su un vettore di variabili dummy
ds.Gender.replace({'male':1,'female':0},inplace=True)

# %%
ds.head(10)
# Out:
#     Gender EthnicGroup          ParentEduc ParentMaritalStatus PracticeSport  \
# 2        0     group B     master's degree              single     sometimes
# 4        1     group C        some college             married     sometimes
# 5        0     group B  associate's degree             married     regularly
# 6        0     group B        some college             widowed         never
# 7        1     group B        some college             married     sometimes
# 8        1     group D         high school              single     sometimes
# 11       1     group D  associate's degree            divorced     sometimes
# 12       0     group B         high school             married     regularly
# 13       1     group A        some college              single     sometimes
# 14       0     group A     master's degree            divorced     sometimes
#
#    IsFirstChild  NrSiblings TransportMeans WklyStudyHours  MathScore  \
# 2           yes         4.0     school_bus            < 5         87
# 4           yes         0.0     school_bus         5 - 10         76
# 5           yes         1.0     school_bus         5 - 10         73
# 6            no         1.0        private         5 - 10         85
# 7           yes         1.0        private           > 10         41
# 8            no         3.0        private           > 10         65
# 11          yes         1.0     school_bus         5 - 10         40
# 12           no         1.0        private         5 - 10         66
# 13          yes         1.0        private           > 10         80
# 14          yes         2.0        private            < 5         48
#
#     ReadingScore  WritingScore
# 2             93            91
# 4             78            75
# 5             84            79
# 6             93            89
# 7             43            39
# 8             64            68
# 11            52            43
# 12            82            74
# 13            73            71
# 14            53            58

# %%
ds_= pd.get_dummies(ds['EthnicGroup'], prefix='EG')
ds = ds.join(ds_).drop('EthnicGroup',axis=1)

# %%
ds.head(10)
# Out:
#     Gender          ParentEduc ParentMaritalStatus PracticeSport IsFirstChild  \
# 2        0     master's degree              single     sometimes          yes
# 4        1        some college             married     sometimes          yes
# 5        0  associate's degree             married     regularly          yes
# 6        0        some college             widowed         never           no
# 7        1        some college             married     sometimes          yes
# 8        1         high school              single     sometimes           no
# 11       1  associate's degree            divorced     sometimes          yes
# 12       0         high school             married     regularly           no
# 13       1        some college              single     sometimes          yes
# 14       0     master's degree            divorced     sometimes          yes
#
#     NrSiblings TransportMeans WklyStudyHours  MathScore  ReadingScore  \
# 2          4.0     school_bus            < 5         87            93
# 4          0.0     school_bus         5 - 10         76            78
# 5          1.0     school_bus         5 - 10         73            84
# 6          1.0        private         5 - 10         85            93
# 7          1.0        private           > 10         41            43
# 8          3.0        private           > 10         65            64
# 11         1.0     school_bus         5 - 10         40            52
# 12         1.0        private         5 - 10         66            82
# 13         1.0        private           > 10         80            73
# 14         2.0        private            < 5         48            53
#
#     WritingScore  EG_group A  EG_group B  EG_group C  EG_group D  EG_group E
# 2             91       False        True       False       False       False
# 4             75       False       False        True       False       False
# 5             79       False        True       False       False       False
# 6             89       False        True       False       False       False
# 7             39       False        True       False       False       False
# 8             68       False       False       False        True       False
# 11            43       False       False       False        True       False
# 12            74       False        True       False       False       False
# 13            71        True       False       False       False       False
# 14            58        True       False       False       False       False

# %%
ds_= pd.get_dummies(ds['ParentEduc'], prefix='ParEduc')
ds = ds.join(ds_).drop('ParentEduc',axis=1)

# %%
ds.head(10)
# Out:
#     Gender ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 2        0              single     sometimes          yes         4.0
# 4        1             married     sometimes          yes         0.0
# 5        0             married     regularly          yes         1.0
# 6        0             widowed         never           no         1.0
# 7        1             married     sometimes          yes         1.0
# 8        1              single     sometimes           no         3.0
# 11       1            divorced     sometimes          yes         1.0
# 12       0             married     regularly           no         1.0
# 13       1              single     sometimes          yes         1.0
# 14       0            divorced     sometimes          yes         2.0
#
#    TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore  ...  \
# 2      school_bus            < 5         87            93            91  ...
# 4      school_bus         5 - 10         76            78            75  ...
# 5      school_bus         5 - 10         73            84            79  ...
# 6         private         5 - 10         85            93            89  ...
# 7         private           > 10         41            43            39  ...
# 8         private           > 10         65            64            68  ...
# 11     school_bus         5 - 10         40            52            43  ...
# 12        private         5 - 10         66            82            74  ...
# 13        private           > 10         80            73            71  ...
# 14        private            < 5         48            53            58  ...
#
#     EG_group B  EG_group C  EG_group D  EG_group E  \
# 2         True       False       False       False
# 4        False        True       False       False
# 5         True       False       False       False
# 6         True       False       False       False
# 7         True       False       False       False
# 8        False       False        True       False
# 11       False       False        True       False
# 12        True       False       False       False
# 13       False       False       False       False
# 14       False       False       False       False
#
#     ParEduc_associate's degree  ParEduc_bachelor's degree  \
# 2                        False                      False
# 4                        False                      False
# 5                         True                      False
# 6                        False                      False
# 7                        False                      False
# 8                        False                      False
# 11                        True                      False
# 12                       False                      False
# 13                       False                      False
# 14                       False                      False
#
#     ParEduc_high school  ParEduc_master's degree  ParEduc_some college  \
# 2                 False                     True                 False
# 4                 False                    False                  True
# 5                 False                    False                 False
# 6                 False                    False                  True
# 7                 False                    False                  True
# 8                  True                    False                 False
# 11                False                    False                 False
# 12                 True                    False                 False
# 13                False                    False                  True
# 14                False                     True                 False
#
#     ParEduc_some high school
# 2                      False
# 4                      False
# 5                      False
# 6                      False
# 7                      False
# 8                      False
# 11                     False
# 12                     False
# 13                     False
# 14                     False
#
# [10 rows x 21 columns]

# %%
ds_= pd.get_dummies(ds['ParentMaritalStatus'], prefix='ParMarStat')
ds = ds.join(ds_).drop('ParentMaritalStatus',axis=1)

# %%
ds.head(10)
# Out:
#     Gender PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 2        0     sometimes          yes         4.0     school_bus
# 4        1     sometimes          yes         0.0     school_bus
# 5        0     regularly          yes         1.0     school_bus
# 6        0         never           no         1.0        private
# 7        1     sometimes          yes         1.0        private
# 8        1     sometimes           no         3.0        private
# 11       1     sometimes          yes         1.0     school_bus
# 12       0     regularly           no         1.0        private
# 13       1     sometimes          yes         1.0        private
# 14       0     sometimes          yes         2.0        private
#
#    WklyStudyHours  MathScore  ReadingScore  WritingScore  EG_group A  ...  \
# 2             < 5         87            93            91       False  ...
# 4          5 - 10         76            78            75       False  ...
# 5          5 - 10         73            84            79       False  ...
# 6          5 - 10         85            93            89       False  ...
# 7            > 10         41            43            39       False  ...
# 8            > 10         65            64            68       False  ...
# 11         5 - 10         40            52            43       False  ...
# 12         5 - 10         66            82            74       False  ...
# 13           > 10         80            73            71        True  ...
# 14            < 5         48            53            58        True  ...
#
#     ParEduc_associate's degree  ParEduc_bachelor's degree  \
# 2                        False                      False
# 4                        False                      False
# 5                         True                      False
# 6                        False                      False
# 7                        False                      False
# 8                        False                      False
# 11                        True                      False
# 12                       False                      False
# 13                       False                      False
# 14                       False                      False
#
#     ParEduc_high school  ParEduc_master's degree  ParEduc_some college  \
# 2                 False                     True                 False
# 4                 False                    False                  True
# 5                 False                    False                 False
# 6                 False                    False                  True
# 7                 False                    False                  True
# 8                  True                    False                 False
# 11                False                    False                 False
# 12                 True                    False                 False
# 13                False                    False                  True
# 14                False                     True                 False
#
#     ParEduc_some high school  ParMarStat_divorced  ParMarStat_married  \
# 2                      False                False               False
# 4                      False                False                True
# 5                      False                False                True
# 6                      False                False               False
# 7                      False                False                True
# 8                      False                False               False
# 11                     False                 True               False
# 12                     False                False                True
# 13                     False                False               False
# 14                     False                 True               False
#
#     ParMarStat_single  ParMarStat_widowed
# 2                True               False
# 4               False               False
# 5               False               False
# 6               False                True
# 7               False               False
# 8                True               False
# 11              False               False
# 12              False               False
# 13               True               False
# 14              False               False
#
# [10 rows x 24 columns]

# %%
ds_= pd.get_dummies(ds['PracticeSport'], prefix='sport')
ds = ds.join(ds_).drop('PracticeSport',axis=1)

# %%
ds.head(10)
# Out:
#     Gender IsFirstChild  NrSiblings TransportMeans WklyStudyHours  MathScore  \
# 2        0          yes         4.0     school_bus            < 5         87
# 4        1          yes         0.0     school_bus         5 - 10         76
# 5        0          yes         1.0     school_bus         5 - 10         73
# 6        0           no         1.0        private         5 - 10         85
# 7        1          yes         1.0        private           > 10         41
# 8        1           no         3.0        private           > 10         65
# 11       1          yes         1.0     school_bus         5 - 10         40
# 12       0           no         1.0        private         5 - 10         66
# 13       1          yes         1.0        private           > 10         80
# 14       0          yes         2.0        private            < 5         48
#
#     ReadingScore  WritingScore  EG_group A  EG_group B  ...  \
# 2             93            91       False        True  ...
# 4             78            75       False       False  ...
# 5             84            79       False        True  ...
# 6             93            89       False        True  ...
# 7             43            39       False        True  ...
# 8             64            68       False       False  ...
# 11            52            43       False       False  ...
# 12            82            74       False        True  ...
# 13            73            71        True       False  ...
# 14            53            58        True       False  ...
#
#     ParEduc_master's degree  ParEduc_some college  ParEduc_some high school  \
# 2                      True                 False                     False
# 4                     False                  True                     False
# 5                     False                 False                     False
# 6                     False                  True                     False
# 7                     False                  True                     False
# 8                     False                 False                     False
# 11                    False                 False                     False
# 12                    False                 False                     False
# 13                    False                  True                     False
# 14                     True                 False                     False
#
#     ParMarStat_divorced  ParMarStat_married  ParMarStat_single  \
# 2                 False               False               True
# 4                 False                True              False
# 5                 False                True              False
# 6                 False               False              False
# 7                 False                True              False
# 8                 False               False               True
# 11                 True               False              False
# 12                False                True              False
# 13                False               False               True
# 14                 True               False              False
#
#     ParMarStat_widowed  sport_never  sport_regularly  sport_sometimes
# 2                False        False            False             True
# 4                False        False            False             True
# 5                False        False             True            False
# 6                 True         True            False            False
# 7                False        False            False             True
# 8                False        False            False             True
# 11               False        False            False             True
# 12               False        False             True            False
# 13               False        False            False             True
# 14               False        False            False             True
#
# [10 rows x 26 columns]

# %%
ds.IsFirstChild.replace({'yes':1,'no':0},inplace=True)

# %%
ds.TransportMeans.replace({'school_bus':1,'private':0},inplace=True)

# %%
ds_= pd.get_dummies(ds['WklyStudyHours'], prefix='studyHours')
ds = ds.join(ds_).drop('WklyStudyHours',axis=1)

# %%
ds.head(10)
# Out:
#     Gender  IsFirstChild  NrSiblings  TransportMeans  MathScore  ReadingScore  \
# 2        0             1         4.0               1         87            93
# 4        1             1         0.0               1         76            78
# 5        0             1         1.0               1         73            84
# 6        0             0         1.0               0         85            93
# 7        1             1         1.0               0         41            43
# 8        1             0         3.0               0         65            64
# 11       1             1         1.0               1         40            52
# 12       0             0         1.0               0         66            82
# 13       1             1         1.0               0         80            73
# 14       0             1         2.0               0         48            53
#
#     WritingScore  EG_group A  EG_group B  EG_group C  ...  \
# 2             91       False        True       False  ...
# 4             75       False       False        True  ...
# 5             79       False        True       False  ...
# 6             89       False        True       False  ...
# 7             39       False        True       False  ...
# 8             68       False       False       False  ...
# 11            43       False       False       False  ...
# 12            74       False        True       False  ...
# 13            71        True       False       False  ...
# 14            58        True       False       False  ...
#
#     ParMarStat_divorced  ParMarStat_married  ParMarStat_single  \
# 2                 False               False               True
# 4                 False                True              False
# 5                 False                True              False
# 6                 False               False              False
# 7                 False                True              False
# 8                 False               False               True
# 11                 True               False              False
# 12                False                True              False
# 13                False               False               True
# 14                 True               False              False
#
#     ParMarStat_widowed  sport_never  sport_regularly  sport_sometimes  \
# 2                False        False            False             True
# 4                False        False            False             True
# 5                False        False             True            False
# 6                 True         True            False            False
# 7                False        False            False             True
# 8                False        False            False             True
# 11               False        False            False             True
# 12               False        False             True            False
# 13               False        False            False             True
# 14               False        False            False             True
#
#     studyHours_5 - 10  studyHours_< 5  studyHours_> 10
# 2               False            True            False
# 4                True           False            False
# 5                True           False            False
# 6                True           False            False
# 7               False           False             True
# 8               False           False             True
# 11               True           False            False
# 12               True           False            False
# 13              False           False             True
# 14              False            True            False
#
# [10 rows x 28 columns]

# %%
#Analisi della correlazione (Da fare)
ds.corr()
# Out:
#                               Gender  IsFirstChild  NrSiblings  \
# Gender                      1.000000      0.007530    0.000019
# IsFirstChild                0.007530      1.000000   -0.118518
# NrSiblings                  0.000019     -0.118518    1.000000
# TransportMeans              0.009272     -0.006172   -0.007003
# MathScore                   0.158184      0.010855    0.001412
# ReadingScore               -0.241175      0.007786    0.000023
# WritingScore               -0.291844      0.002930    0.000497
# EG_group A                  0.000366     -0.006108   -0.003225
# EG_group B                  0.001774      0.009620   -0.003270
# EG_group C                 -0.004822     -0.001608    0.009603
# EG_group D                  0.004960     -0.003452   -0.008666
# EG_group E                 -0.002103      0.000038    0.004263
# ParEduc_associate's degree  0.004386      0.000565    0.001797
# ParEduc_bachelor's degree  -0.004490     -0.010727    0.004613
# ParEduc_high school        -0.006165     -0.000192   -0.003340
# ParEduc_master's degree     0.003524      0.012810   -0.010755
# ParEduc_some college       -0.002038     -0.010042    0.005090
# ParEduc_some high school    0.005408      0.010911   -0.000715
# ParMarStat_divorced        -0.017880      0.006315    0.008595
# ParMarStat_married          0.023862      0.004139   -0.002541
# ParMarStat_single          -0.012066     -0.010799   -0.005760
# ParMarStat_widowed          0.000308      0.001419    0.003585
# sport_never                 0.004070     -0.007475    0.010157
# sport_regularly            -0.011012      0.012657   -0.014937
# sport_sometimes             0.007806     -0.007068    0.007431
# studyHours_5 - 10          -0.002162      0.003647   -0.001762
# studyHours_< 5             -0.004718     -0.002607   -0.001477
# studyHours_> 10             0.008428     -0.001702    0.004063
#
#                             TransportMeans  MathScore  ReadingScore  \
# Gender                            0.009272   0.158184     -0.241175
# IsFirstChild                     -0.006172   0.010855      0.007786
# NrSiblings                       -0.007003   0.001412      0.000023
# TransportMeans                    1.000000   0.006468      0.001207
# MathScore                         0.006468   1.000000      0.819359
# ReadingScore                      0.001207   0.819359      1.000000
# WritingScore                      0.001111   0.808763      0.952529
# EG_group A                       -0.015361  -0.067136     -0.054520
# EG_group B                        0.009188  -0.101250     -0.074271
# EG_group C                       -0.012348  -0.087882     -0.045133
# EG_group D                        0.009053   0.045077      0.041826
# EG_group E                        0.006272   0.229605      0.135464
# ParEduc_associate's degree       -0.002839   0.063087      0.062614
# ParEduc_bachelor's degree        -0.000561   0.096594      0.100232
# ParEduc_high school               0.007178  -0.073156     -0.074979
# ParEduc_master's degree           0.004248   0.102564      0.119413
# ParEduc_some college             -0.001320  -0.004899     -0.011260
# ParEduc_some high school         -0.005276  -0.130212     -0.134973
# ParMarStat_divorced              -0.001565   0.002498      0.007054
# ParMarStat_married               -0.001477   0.007192     -0.001242
# ParMarStat_single                 0.002394  -0.013471     -0.006957
# ParMarStat_widowed                0.002130   0.009073      0.006802
# sport_never                      -0.002100  -0.055001     -0.023531
# sport_regularly                  -0.002341   0.052218      0.023923
# sport_sometimes                   0.003679  -0.012702     -0.006955
# studyHours_5 - 10                -0.004566   0.024014      0.019571
# studyHours_< 5                    0.012238  -0.081851     -0.047154
# studyHours_> 10                  -0.008499   0.065405      0.030146
#
#                             WritingScore  EG_group A  EG_group B  EG_group C  \
# Gender                         -0.291844    0.000366    0.001774   -0.004822
# IsFirstChild                    0.002930   -0.006108    0.009620   -0.001608
# NrSiblings                      0.000497   -0.003225   -0.003270    0.009603
# TransportMeans                  0.001111   -0.015361    0.009188   -0.012348
# MathScore                       0.808763   -0.067136   -0.101250   -0.087882
# ReadingScore                    0.952529   -0.054520   -0.074271   -0.045133
# WritingScore                    1.000000   -0.064233   -0.084912   -0.064477
# EG_group A                     -0.064233    1.000000   -0.145082   -0.197617
# EG_group B                     -0.084912   -0.145082    1.000000   -0.347321
# EG_group C                     -0.064477   -0.197617   -0.347321    1.000000
# EG_group D                      0.095919   -0.169704   -0.298262   -0.406266
# EG_group E                      0.113049   -0.116292   -0.204388   -0.278399
# ParEduc_associate's degree      0.064883    0.000132    0.006365   -0.003216
# ParEduc_bachelor's degree       0.125320    0.007997   -0.013666    0.003265
# ParEduc_high school            -0.099405    0.006814    0.009432   -0.005820
# ParEduc_master's degree         0.139721   -0.015577    0.004240    0.009879
# ParEduc_some college           -0.000830   -0.001175   -0.012233   -0.005690
# ParEduc_some high school       -0.157516   -0.002243    0.005644    0.006155
# ParMarStat_divorced             0.009324    0.004278   -0.010895   -0.005856
# ParMarStat_married             -0.004662   -0.002040   -0.001810    0.008973
# ParMarStat_single              -0.004597   -0.002900    0.013445   -0.004902
# ParMarStat_widowed              0.005602    0.004655   -0.005505   -0.001106
# sport_never                    -0.043971   -0.011206    0.006033   -0.002461
# sport_regularly                 0.053672   -0.004125   -0.007204    0.002591
# sport_sometimes                -0.021611    0.011595    0.002812   -0.000813
# studyHours_5 - 10               0.014229    0.003167    0.001294    0.005258
# studyHours_< 5                 -0.050153   -0.004679   -0.000486    0.005841
# studyHours_> 10                 0.040713    0.001382   -0.001124   -0.013825
#
#                             ...  ParMarStat_divorced  ParMarStat_married  \
# Gender                      ...            -0.017880            0.023862
# IsFirstChild                ...             0.006315            0.004139
# NrSiblings                  ...             0.008595           -0.002541
# TransportMeans              ...            -0.001565           -0.001477
# MathScore                   ...             0.002498            0.007192
# ReadingScore                ...             0.007054           -0.001242
# WritingScore                ...             0.009324           -0.004662
# EG_group A                  ...             0.004278           -0.002040
# EG_group B                  ...            -0.010895           -0.001810
# EG_group C                  ...            -0.005856            0.008973
# EG_group D                  ...             0.016963           -0.005377
# EG_group E                  ...            -0.004156           -0.001625
# ParEduc_associate's degree  ...            -0.008471           -0.003890
# ParEduc_bachelor's degree   ...             0.001401           -0.005459
# ParEduc_high school         ...             0.010370           -0.001997
# ParEduc_master's degree     ...             0.008550           -0.005714
# ParEduc_some college        ...            -0.006403            0.012363
# ParEduc_some high school    ...            -0.001772            0.000869
# ParMarStat_divorced         ...             1.000000           -0.520953
# ParMarStat_married          ...            -0.520953            1.000000
# ParMarStat_single           ...            -0.253126           -0.648909
# ParMarStat_widowed          ...            -0.063680           -0.163249
# sport_never                 ...            -0.003166            0.003748
# sport_regularly             ...             0.000700           -0.003722
# sport_sometimes             ...             0.001484            0.001023
# studyHours_5 - 10           ...            -0.003107           -0.001989
# studyHours_< 5              ...             0.002161           -0.002546
# studyHours_> 10             ...             0.001522            0.005629
#
#                             ParMarStat_single  ParMarStat_widowed  \
# Gender                              -0.012066            0.000308
# IsFirstChild                        -0.010799            0.001419
# NrSiblings                          -0.005760            0.003585
# TransportMeans                       0.002394            0.002130
# MathScore                           -0.013471            0.009073
# ReadingScore                        -0.006957            0.006802
# WritingScore                        -0.004597            0.005602
# EG_group A                          -0.002900            0.004655
# EG_group B                           0.013445           -0.005505
# EG_group C                          -0.004902           -0.001106
# EG_group D                          -0.007227           -0.004402
# EG_group E                           0.002338            0.009843
# ParEduc_associate's degree           0.014235           -0.007068
# ParEduc_bachelor's degree            0.000200            0.015095
# ParEduc_high school                 -0.006327           -0.001414
# ParEduc_master's degree             -0.005005            0.012711
# ParEduc_some college                -0.005641           -0.009461
# ParEduc_some high school             0.001174           -0.001930
# ParMarStat_divorced                 -0.253126           -0.063680
# ParMarStat_married                  -0.648909           -0.163249
# ParMarStat_single                    1.000000           -0.079321
# ParMarStat_widowed                  -0.079321            1.000000
# sport_never                         -0.002390            0.002542
# sport_regularly                      0.005223           -0.004697
# sport_sometimes                     -0.003389            0.002780
# studyHours_5 - 10                    0.003757            0.003930
# studyHours_< 5                       0.002323           -0.003908
# studyHours_> 10                     -0.007687           -0.000533
#
#                             sport_never  sport_regularly  sport_sometimes  \
# Gender                         0.004070        -0.011012         0.007806
# IsFirstChild                  -0.007475         0.012657        -0.007068
# NrSiblings                     0.010157        -0.014937         0.007431
# TransportMeans                -0.002100        -0.002341         0.003679
# MathScore                     -0.055001         0.052218        -0.012702
# ReadingScore                  -0.023531         0.023923        -0.006955
# WritingScore                  -0.043971         0.053672        -0.021611
# EG_group A                    -0.011206        -0.004125         0.011595
# EG_group B                     0.006033        -0.007204         0.002812
# EG_group C                    -0.002461         0.002591        -0.000813
# EG_group D                     0.003965         0.003302        -0.005873
# EG_group E                    -0.000116         0.003846        -0.003615
# ParEduc_associate's degree     0.002100        -0.007646         0.005915
# ParEduc_bachelor's degree     -0.010699         0.006623         0.000924
# ParEduc_high school            0.001894        -0.013587         0.011762
# ParEduc_master's degree        0.016652        -0.008668        -0.003015
# ParEduc_some college          -0.002547         0.013371        -0.011109
# ParEduc_some high school      -0.003303         0.007292        -0.004755
# ParMarStat_divorced           -0.003166         0.000700         0.001484
# ParMarStat_married             0.003748        -0.003722         0.001023
# ParMarStat_single             -0.002390         0.005223        -0.003389
# ParMarStat_widowed             0.002542        -0.004697         0.002780
# sport_never                    1.000000        -0.295479        -0.397223
# sport_regularly               -0.295479         1.000000        -0.759374
# sport_sometimes               -0.397223        -0.759374         1.000000
# studyHours_5 - 10              0.002075        -0.010140         0.008328
# studyHours_< 5                -0.007725         0.008887        -0.003275
# studyHours_> 10                0.006425         0.002793        -0.007059
#
#                             studyHours_5 - 10  studyHours_< 5  studyHours_> 10
# Gender                              -0.002162       -0.004718         0.008428
# IsFirstChild                         0.003647       -0.002607        -0.001702
# NrSiblings                          -0.001762       -0.001477         0.004063
# TransportMeans                      -0.004566        0.012238        -0.008499
# MathScore                            0.024014       -0.081851         0.065405
# ReadingScore                         0.019571       -0.047154         0.030146
# WritingScore                         0.014229       -0.050153         0.040713
# EG_group A                           0.003167       -0.004679         0.001382
# EG_group B                           0.001294       -0.000486        -0.001124
# EG_group C                           0.005258        0.005841        -0.013825
# EG_group D                          -0.013468        0.001934         0.015399
# EG_group E                           0.005985       -0.006144        -0.000583
# ParEduc_associate's degree           0.008357       -0.009333         0.000077
# ParEduc_bachelor's degree            0.001262        0.007276        -0.010276
# ParEduc_high school                  0.015607       -0.011638        -0.006715
# ParEduc_master's degree             -0.011647        0.008850         0.004816
# ParEduc_some college                -0.003773        0.003002         0.001400
# ParEduc_some high school            -0.013666        0.006256         0.010539
# ParMarStat_divorced                 -0.003107        0.002161         0.001522
# ParMarStat_married                  -0.001989       -0.002546         0.005629
# ParMarStat_single                    0.003757        0.002323        -0.007687
# ParMarStat_widowed                   0.003930       -0.003908        -0.000533
# sport_never                          0.002075       -0.007725         0.006425
# sport_regularly                     -0.010140        0.008887         0.002793
# sport_sometimes                      0.008328       -0.003275        -0.007059
# studyHours_5 - 10                    1.000000       -0.683954        -0.503358
# studyHours_< 5                      -0.683954        1.000000        -0.286093
# studyHours_> 10                     -0.503358       -0.286093         1.000000
#
# [28 rows x 28 columns]

# %%
#Reading e writing sono altamente correlati, li aggreghiamo facendone la media
new = pd.Series((ds.ReadingScore+ds.WritingScore)/2,name='RWScore')

# %%
ds.drop(['ReadingScore','WritingScore'],axis=1,inplace=True)
ds = ds.join(new)

# %%
ds.head(10)
# Out:
#     Gender  IsFirstChild  NrSiblings  TransportMeans  MathScore  EG_group A  \
# 2        0             1         4.0               1         87       False
# 4        1             1         0.0               1         76       False
# 5        0             1         1.0               1         73       False
# 6        0             0         1.0               0         85       False
# 7        1             1         1.0               0         41       False
# 8        1             0         3.0               0         65       False
# 11       1             1         1.0               1         40       False
# 12       0             0         1.0               0         66       False
# 13       1             1         1.0               0         80        True
# 14       0             1         2.0               0         48        True
#
#     EG_group B  EG_group C  EG_group D  EG_group E  ...  ParMarStat_married  \
# 2         True       False       False       False  ...               False
# 4        False        True       False       False  ...                True
# 5         True       False       False       False  ...                True
# 6         True       False       False       False  ...               False
# 7         True       False       False       False  ...                True
# 8        False       False        True       False  ...               False
# 11       False       False        True       False  ...               False
# 12        True       False       False       False  ...                True
# 13       False       False       False       False  ...               False
# 14       False       False       False       False  ...               False
#
#     ParMarStat_single  ParMarStat_widowed  sport_never  sport_regularly  \
# 2                True               False        False            False
# 4               False               False        False            False
# 5               False               False        False             True
# 6               False                True         True            False
# 7               False               False        False            False
# 8                True               False        False            False
# 11              False               False        False            False
# 12              False               False        False             True
# 13               True               False        False            False
# 14              False               False        False            False
#
#     sport_sometimes  studyHours_5 - 10  studyHours_< 5  studyHours_> 10  \
# 2              True              False            True            False
# 4              True               True           False            False
# 5             False               True           False            False
# 6             False               True           False            False
# 7              True              False           False             True
# 8              True              False           False             True
# 11             True               True           False            False
# 12            False               True           False            False
# 13             True              False           False             True
# 14             True              False            True            False
#
#     RWScore
# 2      92.0
# 4      76.5
# 5      81.5
# 6      91.0
# 7      41.0
# 8      66.0
# 11     47.5
# 12     78.0
# 13     72.0
# 14     55.5
#
# [10 rows x 27 columns]

# %%
ds.corr()
# Out:
#                               Gender  IsFirstChild  NrSiblings  \
# Gender                      1.000000      0.007530    0.000019
# IsFirstChild                0.007530      1.000000   -0.118518
# NrSiblings                  0.000019     -0.118518    1.000000
# TransportMeans              0.009272     -0.006172   -0.007003
# MathScore                   0.158184      0.010855    0.001412
# EG_group A                  0.000366     -0.006108   -0.003225
# EG_group B                  0.001774      0.009620   -0.003270
# EG_group C                 -0.004822     -0.001608    0.009603
# EG_group D                  0.004960     -0.003452   -0.008666
# EG_group E                 -0.002103      0.000038    0.004263
# ParEduc_associate's degree  0.004386      0.000565    0.001797
# ParEduc_bachelor's degree  -0.004490     -0.010727    0.004613
# ParEduc_high school        -0.006165     -0.000192   -0.003340
# ParEduc_master's degree     0.003524      0.012810   -0.010755
# ParEduc_some college       -0.002038     -0.010042    0.005090
# ParEduc_some high school    0.005408      0.010911   -0.000715
# ParMarStat_divorced        -0.017880      0.006315    0.008595
# ParMarStat_married          0.023862      0.004139   -0.002541
# ParMarStat_single          -0.012066     -0.010799   -0.005760
# ParMarStat_widowed          0.000308      0.001419    0.003585
# sport_never                 0.004070     -0.007475    0.010157
# sport_regularly            -0.011012      0.012657   -0.014937
# sport_sometimes             0.007806     -0.007068    0.007431
# studyHours_5 - 10          -0.002162      0.003647   -0.001762
# studyHours_< 5             -0.004718     -0.002607   -0.001477
# studyHours_> 10             0.008428     -0.001702    0.004063
# RWScore                    -0.270328      0.005365    0.000269
#
#                             TransportMeans  MathScore  EG_group A  EG_group B  \
# Gender                            0.009272   0.158184    0.000366    0.001774
# IsFirstChild                     -0.006172   0.010855   -0.006108    0.009620
# NrSiblings                       -0.007003   0.001412   -0.003225   -0.003270
# TransportMeans                    1.000000   0.006468   -0.015361    0.009188
# MathScore                         0.006468   1.000000   -0.067136   -0.101250
# EG_group A                       -0.015361  -0.067136    1.000000   -0.145082
# EG_group B                        0.009188  -0.101250   -0.145082    1.000000
# EG_group C                       -0.012348  -0.087882   -0.197617   -0.347321
# EG_group D                        0.009053   0.045077   -0.169704   -0.298262
# EG_group E                        0.006272   0.229605   -0.116292   -0.204388
# ParEduc_associate's degree       -0.002839   0.063087    0.000132    0.006365
# ParEduc_bachelor's degree        -0.000561   0.096594    0.007997   -0.013666
# ParEduc_high school               0.007178  -0.073156    0.006814    0.009432
# ParEduc_master's degree           0.004248   0.102564   -0.015577    0.004240
# ParEduc_some college             -0.001320  -0.004899   -0.001175   -0.012233
# ParEduc_some high school         -0.005276  -0.130212   -0.002243    0.005644
# ParMarStat_divorced              -0.001565   0.002498    0.004278   -0.010895
# ParMarStat_married               -0.001477   0.007192   -0.002040   -0.001810
# ParMarStat_single                 0.002394  -0.013471   -0.002900    0.013445
# ParMarStat_widowed                0.002130   0.009073    0.004655   -0.005505
# sport_never                      -0.002100  -0.055001   -0.011206    0.006033
# sport_regularly                  -0.002341   0.052218   -0.004125   -0.007204
# sport_sometimes                   0.003679  -0.012702    0.011595    0.002812
# studyHours_5 - 10                -0.004566   0.024014    0.003167    0.001294
# studyHours_< 5                    0.012238  -0.081851   -0.004679   -0.000486
# studyHours_> 10                  -0.008499   0.065405    0.001382   -0.001124
# RWScore                           0.001172   0.823766   -0.060208   -0.080679
#
#                             EG_group C  EG_group D  EG_group E  ...  \
# Gender                       -0.004822    0.004960   -0.002103  ...
# IsFirstChild                 -0.001608   -0.003452    0.000038  ...
# NrSiblings                    0.009603   -0.008666    0.004263  ...
# TransportMeans               -0.012348    0.009053    0.006272  ...
# MathScore                    -0.087882    0.045077    0.229605  ...
# EG_group A                   -0.197617   -0.169704   -0.116292  ...
# EG_group B                   -0.347321   -0.298262   -0.204388  ...
# EG_group C                    1.000000   -0.406266   -0.278399  ...
# EG_group D                   -0.406266    1.000000   -0.239076  ...
# EG_group E                   -0.278399   -0.239076    1.000000  ...
# ParEduc_associate's degree   -0.003216   -0.002026   -0.000596  ...
# ParEduc_bachelor's degree     0.003265    0.001693    0.003194  ...
# ParEduc_high school          -0.005820   -0.001962   -0.005828  ...
# ParEduc_master's degree       0.009879   -0.001340   -0.004594  ...
# ParEduc_some college         -0.005690    0.012984    0.006342  ...
# ParEduc_some high school      0.006155   -0.010427    0.000047  ...
# ParMarStat_divorced          -0.005856    0.016963   -0.004156  ...
# ParMarStat_married            0.008973   -0.005377   -0.001625  ...
# ParMarStat_single            -0.004902   -0.007227    0.002338  ...
# ParMarStat_widowed           -0.001106   -0.004402    0.009843  ...
# sport_never                  -0.002461    0.003965   -0.000116  ...
# sport_regularly               0.002591    0.003302    0.003846  ...
# sport_sometimes              -0.000813   -0.005873   -0.003615  ...
# studyHours_5 - 10             0.005258   -0.013468    0.005985  ...
# studyHours_< 5                0.005841    0.001934   -0.006144  ...
# studyHours_> 10              -0.013825    0.015399   -0.000583  ...
# RWScore                      -0.055696    0.070345    0.125492  ...
#
#                             ParMarStat_married  ParMarStat_single  \
# Gender                                0.023862          -0.012066
# IsFirstChild                          0.004139          -0.010799
# NrSiblings                           -0.002541          -0.005760
# TransportMeans                       -0.001477           0.002394
# MathScore                             0.007192          -0.013471
# EG_group A                           -0.002040          -0.002900
# EG_group B                           -0.001810           0.013445
# EG_group C                            0.008973          -0.004902
# EG_group D                           -0.005377          -0.007227
# EG_group E                           -0.001625           0.002338
# ParEduc_associate's degree           -0.003890           0.014235
# ParEduc_bachelor's degree            -0.005459           0.000200
# ParEduc_high school                  -0.001997          -0.006327
# ParEduc_master's degree              -0.005714          -0.005005
# ParEduc_some college                  0.012363          -0.005641
# ParEduc_some high school              0.000869           0.001174
# ParMarStat_divorced                  -0.520953          -0.253126
# ParMarStat_married                    1.000000          -0.648909
# ParMarStat_single                    -0.648909           1.000000
# ParMarStat_widowed                   -0.163249          -0.079321
# sport_never                           0.003748          -0.002390
# sport_regularly                      -0.003722           0.005223
# sport_sometimes                       0.001023          -0.003389
# studyHours_5 - 10                    -0.001989           0.003757
# studyHours_< 5                       -0.002546           0.002323
# studyHours_> 10                       0.005629          -0.007687
# RWScore                              -0.003028          -0.005819
#
#                             ParMarStat_widowed  sport_never  sport_regularly  \
# Gender                                0.000308     0.004070        -0.011012
# IsFirstChild                          0.001419    -0.007475         0.012657
# NrSiblings                            0.003585     0.010157        -0.014937
# TransportMeans                        0.002130    -0.002100        -0.002341
# MathScore                             0.009073    -0.055001         0.052218
# EG_group A                            0.004655    -0.011206        -0.004125
# EG_group B                           -0.005505     0.006033        -0.007204
# EG_group C                           -0.001106    -0.002461         0.002591
# EG_group D                           -0.004402     0.003965         0.003302
# EG_group E                            0.009843    -0.000116         0.003846
# ParEduc_associate's degree           -0.007068     0.002100        -0.007646
# ParEduc_bachelor's degree             0.015095    -0.010699         0.006623
# ParEduc_high school                  -0.001414     0.001894        -0.013587
# ParEduc_master's degree               0.012711     0.016652        -0.008668
# ParEduc_some college                 -0.009461    -0.002547         0.013371
# ParEduc_some high school             -0.001930    -0.003303         0.007292
# ParMarStat_divorced                  -0.063680    -0.003166         0.000700
# ParMarStat_married                   -0.163249     0.003748        -0.003722
# ParMarStat_single                    -0.079321    -0.002390         0.005223
# ParMarStat_widowed                    1.000000     0.002542        -0.004697
# sport_never                           0.002542     1.000000        -0.295479
# sport_regularly                      -0.004697    -0.295479         1.000000
# sport_sometimes                       0.002780    -0.397223        -0.759374
# studyHours_5 - 10                     0.003930     0.002075        -0.010140
# studyHours_< 5                       -0.003908    -0.007725         0.008887
# studyHours_> 10                      -0.000533     0.006425         0.002793
# RWScore                               0.006262    -0.034401         0.039619
#
#                             sport_sometimes  studyHours_5 - 10  \
# Gender                             0.007806          -0.002162
# IsFirstChild                      -0.007068           0.003647
# NrSiblings                         0.007431          -0.001762
# TransportMeans                     0.003679          -0.004566
# MathScore                         -0.012702           0.024014
# EG_group A                         0.011595           0.003167
# EG_group B                         0.002812           0.001294
# EG_group C                        -0.000813           0.005258
# EG_group D                        -0.005873          -0.013468
# EG_group E                        -0.003615           0.005985
# ParEduc_associate's degree         0.005915           0.008357
# ParEduc_bachelor's degree          0.000924           0.001262
# ParEduc_high school                0.011762           0.015607
# ParEduc_master's degree           -0.003015          -0.011647
# ParEduc_some college              -0.011109          -0.003773
# ParEduc_some high school          -0.004755          -0.013666
# ParMarStat_divorced                0.001484          -0.003107
# ParMarStat_married                 0.001023          -0.001989
# ParMarStat_single                 -0.003389           0.003757
# ParMarStat_widowed                 0.002780           0.003930
# sport_never                       -0.397223           0.002075
# sport_regularly                   -0.759374          -0.010140
# sport_sometimes                    1.000000           0.008328
# studyHours_5 - 10                  0.008328           1.000000
# studyHours_< 5                    -0.003275          -0.683954
# studyHours_> 10                   -0.007059          -0.503358
# RWScore                           -0.014629           0.017041
#
#                             studyHours_< 5  studyHours_> 10   RWScore
# Gender                           -0.004718         0.008428 -0.270328
# IsFirstChild                     -0.002607        -0.001702  0.005365
# NrSiblings                       -0.001477         0.004063  0.000269
# TransportMeans                    0.012238        -0.008499  0.001172
# MathScore                        -0.081851         0.065405  0.823766
# EG_group A                       -0.004679         0.001382 -0.060208
# EG_group B                       -0.000486        -0.001124 -0.080679
# EG_group C                        0.005841        -0.013825 -0.055696
# EG_group D                        0.001934         0.015399  0.070345
# EG_group E                       -0.006144        -0.000583  0.125492
# ParEduc_associate's degree       -0.009333         0.000077  0.064545
# ParEduc_bachelor's degree         0.007276        -0.010276  0.114435
# ParEduc_high school              -0.011638        -0.006715 -0.088535
# ParEduc_master's degree           0.008850         0.004816  0.131372
# ParEduc_some college              0.003002         0.001400 -0.005994
# ParEduc_some high school          0.006256         0.010539 -0.148278
# ParMarStat_divorced               0.002161         0.001522  0.008315
# ParMarStat_married               -0.002546         0.005629 -0.003028
# ParMarStat_single                 0.002323        -0.007687 -0.005819
# ParMarStat_widowed               -0.003908        -0.000533  0.006262
# sport_never                      -0.007725         0.006425 -0.034401
# sport_regularly                   0.008887         0.002793  0.039619
# sport_sometimes                  -0.003275        -0.007059 -0.014629
# studyHours_5 - 10                -0.683954        -0.503358  0.017041
# studyHours_< 5                    1.000000        -0.286093 -0.049277
# studyHours_> 10                  -0.286093         1.000000  0.035983
# RWScore                          -0.049277         0.035983  1.000000
#
# [27 rows x 27 columns]

# %%
mat2 =pd.Series(ds.MathScore/10,name='MathScore')
ds.drop('MathScore',axis=1,inplace=True)
ds = ds.join(mat2)
rw2 =pd.Series(ds.RWScore/10,name='RWScore')
ds.drop('RWScore',axis=1,inplace=True)
ds = ds.join(rw2)

# %%
import numpy as np

# %%
np.random.seed(50)

# %% [markdown]
# <h1> Modello SVM </h1>

# %%
#suddivisione del dataset in test set e training set
from sklearn.model_selection import train_test_split
X = ds.drop('MathScore',axis=1)
Y = ds['MathScore']
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
from sklearn.svm import SVR
svr_reg = SVR()
svr_reg.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred_svr= svr_reg.predict(X_train)
mean_squared_error(y_train,y_pred_svr)
# Out:
# 0.34630203393362574

# %%
#performance sul test set
y_pred_svr= svr_reg.predict(X_test)
mean_squared_error(y_test,y_pred_svr)
# Out:
# 0.3576924580672373
